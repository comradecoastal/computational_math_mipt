# %% [markdown]
# Каждый подпункт в каждой задаче оценивается в 0.5 балла. 1.5 + 2.0 + 2.5 + 2.0 + 2.0 = 10.0 - максимальный балл за контрольную.

# %% [markdown]
# ## Задача 1 Численное дифференцирование.

# %% [markdown]
# - Вычислить дивергенцию
# $\quad f(x, y)=\left(f_1(x, y), f_2(x, y)\right)=\left(x^2+y^2, x^2-y^2\right) \quad$ в области $[-2,2] \times[-2,2]$ используя значения gradient для функций $f_1$ и $f_2$, с шагом $h_x=0.1 \quad$ и $\quad h_y=0.1$
#
# - Изобразить дивергенцию на двумерной области в виде цветной картинки (можно, например, использовать визуализацию массивов).
#
#
# Граничный эффект приведет к плохой аппроксимации на соответствующих точках, поэтому, поэтому изобразить дивергенцию надо для области
#
# $\left[-2+h_x, 2-\right.$ $\left.h_x\right] \times\left[-2+h_y \quad, 2-h_y\right]$
#
# - Вычислить интегральную относительную погрешность, используя np.linalg.norm.

# %% [markdown]
# ## Задача 2  Численное интегрирование.

# %% [markdown]
# Для функции $f(x)=\cos x /(2+\sin x)$, вычислить определённый интеграл на отрезке $[2 ; 8]$
#
# - точно, аналитически взяв интеграл
#
# - по формулам прямоугольников, трапеций и Симпсона при $n=12$ разбиении отрезка интегрирования.
#
# - вычислить абсолютную и относительную погрешность по априорным формулам.
#
# - вычислить абсолютную и относительную погрешность по формуле Рунге .
# $$
# \frac{\left|y_{i, h}-y_{i, h / 2}\right|}{2^p-1}
# $$
#
# p - порядок точности использованного численного метода.

# %% [markdown]
# ## Задача 3  Монте-Карло и интегралы.

# %% [markdown]
# - Вычислить как минимум двумя различными способами (методом Монте-Карло) интеграл (Если реализован только один метод, то баллы можно получить только за второй, третий и четвертый пункт).
# - Построить оценки для $N=10^k$ $(k=1,2, \ldots, 6)$ статистических испытаний.
# - Провести статистическую оценку погрешности для выбранной вероятности для каждого $N$, опираясь на центральную предельную теорему. Достаточно в одном из методов.
# - Установить реальную ошибку вычислений для каждого $N$, вычислив интеграл аналитически (или подсмотрев результат в задачнике Демидовича).
# - Выявить, какой метод Монте-Карло (из двух)  оказался предпочтительнее.
#
# \begin{aligned}
# & \int \ldots \int \frac{d x_1 d y_1 d z_1 d x_2 d y_2 d z_2}{r_{12}}, \text { где } G=\left\{x_1^2+y_1^2+z_1^2 \leqslant R^2, x_2^2+y_2^2+z_2^2 \leqslant R^2\right\}, \\
# & r_{12}=\sqrt{\left(x_1-x_2\right)^2+\left(y_1-y_2\right)^2+\left(z_1-z_2\right)^2} .
# \end{aligned}
#
#
#
# Указание: разные способы можно получать, делая замену переменных, или выбирая способ интерпретации интеграла:
#
# 1) интеграл как среднее значение подыинтегральной функции,
#
# 2) интеграл как маотжидание случайной величины с помощью вспомогательной плотности распределения
#
# 3) интеграл как гиперобъем в пространстве размерности на один больше, где переменная, соответствующая новой размерности (координата), изменяется от 0 до значения подынтегральной функции.

# %% [markdown]
# ## Задача 4  Исследование ЭЭГ здоровых подростков и больных шизофренией.

# %% [markdown]
# Имеются два архива данных ЭЭГ для двух групп испытуемых. Испытуемыми были подростки, прошедшие обследование у психиатра и разделенные на две группы: здоровые (n = 39) и с симптомами шизофрении (n = 45).
#
# Каждый файл содержит запись ЭЭГ для одного субъекта. Каждый файл TXT содержит столбец с образцами ЭЭГ из 16 каналов ЭЭГ (положения электродов). Каждое число в столбце представляет собой амплитуду ЭЭГ (мкВ) для отдельной выборки. Первые 7680 отсчетов представляют 1-й канал, затем 7680 - 2-й канал и так далее. Частота дискретизации составляет 128 Гц, таким образом, 7680 выборок относятся к 1 минуте записи ЭЭГ.
#
# Топографическое расположение номеров каналов показано в таблице и на рисунке ниже.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Выберите двух произвольных подростков, одного здорового, а второго с симптомами шизофрении.  Выберите один из 16 каналов. Не забудьте частоту поделить на 60, так как наблюдение велось минуту.
#
# - Используя БПФ, постройте Фурье-спектры для этих двух сигналов и изобразите их на графике (можно на одном, можно отдельно).
#
# - Определите, на какой частоте амплитуда каждого из сигналов максимальна
#
# - Оцените спектральную мощность сигнала альфа-ритма. Для этого проинтегрируйте Фурье-преобразование сигналов в диапазоне от 8 до 13 Гц.
#
# - Постройте рядом графики двух сигналов ЭКГ. Чем они отличаются? Вычислите и сравните дисперсии первого и второго.

# %%
# пример считывания из файла

f = open('S10W1.eea')
inp = f.readlines()
num = [float(k) for k in inp[:7680]  ]
print(num[:50])
f.close()

# %% [markdown]
# ## Задача 5.  Реакция Белоусова–Жаботинского.

# %% [markdown]
# Следующая начальная задача описывает математическую модель известной периодической химической реакции Белоусова-Жаботинского.
# $$
# \left\{\begin{array}{l}
# y_1^{\prime}=77.27\left(y_2+y_1\left(1-8.375 \cdot 10^{-6} y_1-y_2\right)\right), \\
# y_2^{\prime}=\frac{1}{77.27}\left(y_3-\left(1+y_1\right) y_2\right), \\
# y_3^{\prime}=0.161\left(y_1-y_3\right),
# \end{array}\right.
# $$
# $$
# y(0)=(1,2,3)^T .
# $$
#
#
# Наиболее простой (и наименее информативной) характеристикой
# жёстких начальных задач для обыкновенных дифференциальных уравнений является то, что к этим задачам практически неприменимы традиционные явные методы. Поэтому для численного решения следует использовать неявные методы.

# %% [markdown]
# - Численно решите эту систему при указанных значениях параметров.
#
# - Постройте графики этих трех функций в зависимости от времени.
#
# - Нарисуйте трехмерный график решения в координатах $y_1, y_2, y_3$
#
# - Постройте график числа жёсткости в зависимости от времени.
